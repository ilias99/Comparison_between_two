# %%
import subprocess

print(subprocess.call([r"C:/Users/TO125335/Desktop/xpdf-tools-win-4.00/bin64/pdftotext.exe", "G53RP1609842_issue1.2.pdf"]))
# Out:
# 0

# %%
def find_between( s, first, last ):
    
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return "" 
    
import re

# %%
with open('G53RP1609842_issue1.2.txt', 'rt', encoding='latin') as myfile:
    text = myfile.read()

# %%
from docx import Document
# read document docx with docx library
document = Document('G53RP1609842_issue1.2.docx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-66720fd764b8> in <module>()
# ----> 1 from docx import Document
#       2 # read document docx with docx library
#       3 document = Document('G53RP1609842_issue1.2.docx')
#
# ModuleNotFoundError: No module named 'docx'

# %%
for p in document.paragraphs:
    print (p.text)
# Out:
# List of Distribution
#
#
#
#
#
#
# Record of Revisions
#
#
#
#
# Table of contents
# 1	General Notes	1-1
# 1.1	Introduction	1-1
# 1.2	FAR/CS Regulations	1-1
# 1.3	A/C Data Basis and Main Typical Definition or Options	1-1
# 1.4	SRM Principle Description	1-2
# 1.4.1	Rework Analysis	1-2
# 1.4.1.1	Definition of characteristic rework parameters	1-3
# 1.4.1.2	General requirements for reworks	1-4
# 1.4.1.3	Definition of the ‘riveted area’ below a stiffener	1-5
# 1.4.1.4	Rework diagrams	1-6
# 1.4.2	Lightning Strike 50 FC Analysis	1-8
# 1.4.2.1	Burn marks on skin only	1-8
# 1.4.2.2	Burn marks on existing fastener (skin not affected)	1-9
# 1.4.2.3	Burn marks on existing fastener and adjacent skin	1-9
# 1.4.3	Lightning Strike Repair Analysis	1-10
# 1.4.3.1	Temporary repair	1-10
# 1.4.3.1.1	Burn marks on skin	1-10
# 1.4.3.1.2	Burn marks on existing fastener	1-11
# 1.4.3.1.3	Burn marks on existing fastener and / or adjacent skin	1-11
# 1.4.3.1.4	Protruding blind fastener installation	1-12
# ...

# %%
#how many sections we have have in the document
sections = document.sections
print(len(sections))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-520a7825a17c> in <module>()
#       1 #how many sections we have have in the document
# ----> 2 sections = document.sections
#       3 print(len(sections))
#
# NameError: name 'document' is not defined

# %%
for section in sections:
    print(section.start_type)
# Out:
# NEW_PAGE (2)
# NEW_COLUMN (1)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_COLUMN (1)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_PAGE (2)
# NEW_COLUMN (1)

# %%
# read docx document with docx2txt library
import docx2txt
my_text = docx2txt.process("G53RP1609842_issue1.2.docx")

# %%
print(my_text)
# Out:
# A330 NEO - FWD UPPER SHELL - SKIN - SRM - REWORK ABOVE AND BELOW BELLY FAIRING + LIGHTNING STRIKE REPAIR AND ALLOWABLE DAMAGE - METALLIC STATIC STRENGTH
#
# 	ORIGIN LATECOERE
#
# 	PROJECT A330 NEO
#
#
#
# 	REFERENCE   G53RP1609842
#
# 	ISSUE 1.2
#
# 	DATE
# 7 Apr 2017
#
#
#
#
#
# A330 NEO - FWD UPPER SHELL - SKIN - SRM - REWORK ABOVE AND BELOW BELLY FAIRING + LIGHTNING STRIKE REPAIR AND ALLOWABLE DAMAGE - METALLIC STATIC STRENGTH
#
# 	ORIGIN LATECOERE
#
# 	PROJECT A330 NEO
#
#
#
# 	REFERENCE   G53RP1609842
#
# 	ISSUE 1.2
#
# 	DATE
# 7 Apr 2017
#
#
#
#
#
# A330 NEO - FWD UPPER SHELL - SKIN - SRM - REWORK ABOVE AND BELOW BELLY FAIRING + LIGHTNING STRIKE REPAIR AND ALLOWABLE DAMAGE - METALLIC STATIC STRENGTH
#
# 	ORIGIN LATECOERE
#
# 	PROJECT A330 NEO
#
#
#
# 	REFERENCE   G53RP1609842
#
# 	ISSUE 1.2
#
# 	DATE
# 7 Apr 2017
#
#
#
#
#
# A330 NEO - FWD UPPER SHELL - SKIN - SRM - REWORK ABOVE AND BELOW BELLY FAIRING + LIGHTNING STRIKE REPAIR AND ALLOWABLE DAMAGE - METALLIC STATIC STRENGTH
#
# ...

# %%
#5.2 Are the applicable CS/FAR regulations quoted? 
re.sub(' +',' ',find_between(my_text,'Regulation title','Table').replace('\n',' '))!=''
# Out:
# True

# %%
#2.4 all headers are repeated in the beginning of the output, we have one header(and footer) for each section
# all footers are repeated towards the end

#These lines of code check that all sections are formatted with a header and footer which includes the report reference number 
#and issue

hs = find_between(my_text,'REFERENCE','ATA chapter')

def count_occurrences(word, sentence):
    return sentence.lower().split().count(word)

print(count_occurrences(issue.split(' ')[0],hs)) # count how many times string 'issue' is repeated 
print(count_occurrences(issue.split(' ')[1],hs)) # count how many times the number of issue(1. ) is repeated  
print(count_occurrences(ref.lower(),hs))# count how many times reference number is repeated
print(count_occurrences('reference',hs))# count how many times the string 'reference' is repeated


fs = find_between(my_text,'G.1.','Prepared by') + '\n' + find_between(my_text,'Authorized by','PAGE')
print(count_occurrences(date[4:],fs.replace('2017.','2017 .')))

count_occurrences(issue.split(' ')[0],hs) == count_occurrences(issue.split(' ')[1],hs) == count_occurrences(ref.lower(),hs) == (count_occurrences('reference',hs) + 1) == len(sections) +1
# Out:
# 20
# 20
# 20
# 19
# 20
# True

# %%
import os
############ 1.2 Is the correct reference number of the dossier and its issue included in file name? 
base = os.path.basename('G53RP1609842_issue1.2.docx')
name = os.path.splitext(base)[0]
name.split('_')[0]
# Out:
# 'G53RP1609842'

# %%
ref= name.split('_')[0] 
issue = (name.split('_')[1])
print(ref)
issue= issue.replace('issue','issue ')
#print(issue)
issue.split(' ')[1]
# Out:
# G53RP1609842
# '1.2'

# %%
print(issue in find_between(my_text.lower(), 'reference', 'date' )) 
print(ref.lower() in find_between(my_text.lower(), 'reference', 'date' ))
# Out:
# True
# True

# %%
#5.3 Check engine in cover page same as the one in section 1.3
re.sub(' +',' ',find_between(my_text.replace('\n','').replace('\t',''), 'ENGINE applicability', 'ANALYSIS TYPE'))==re.sub(' +',' ',find_between(my_text.replace('\n','').replace('\t',''), 'Engine', 'Loads'))
# Out:
# True

# %%
#5.3 Check ac_applicability in cover page same as the one in section 1.3

ac_applicability=find_between(my_text, 'a/c applicability*', '*Indicate').replace('\n','').replace('-',' ')
ac_applicability
# Out:
# 'LR A330 NEO WV 800 &  900 series'

# %%
ac_type_1_3= find_between(my_text, 'A/C type // A/C standard', 'Load cases').replace('\n','').replace('-',' ')

for element in ac_applicability.split():
    if element in ac_type_1_3.split():
        print(element)
# Out:
# A330
# 800
# 900

# %%
import PyPDF2
from math import floor
from PIL import Image

import sys
from os import path
import warnings
warnings.filterwarnings("ignore")

number = 0

def recurse(xObject,name):
    global number

    xObject = xObject['/Resources']['/XObject'].getObject()

    for obj in xObject:

        if xObject[obj]['/Subtype'] == '/Image':
            size = (xObject[obj]['/Width'], xObject[obj]['/Height'])
            data = xObject[obj]._data
            if xObject[obj]['/ColorSpace'] == '/DeviceRGB':
                mode = "RGB"
            else:
                mode = "P"

            #imagename = "%s - p. %s - %s"%(abspath[:-4], p, obj[1:])

            if xObject[obj]['/Filter'] == '/FlateDecode':
                img = Image.frombytes(mode, size, data)
                img.save(name+".png")
                number += 1
            elif xObject[obj]['/Filter'] == '/DCTDecode':
                img = open(name+".jpg", "wb")
                img.write(data)
                img.close()
                number += 1
            elif xObject[obj]['/Filter'] == '/JPXDecode':
                img = open(name+".jp2", "wb")
                img.write(data)
                img.close()
                number += 1
        #else:
            #recurse(page, xObject[obj])

#try:
#    _, filename, *pages = sys.argv
#    *pages, = map(int, pages)
#    abspath = path.abspath(filename)
#except BaseException:
#    print('Usage :\nPDF_extract_images file.pdf page1 page2 page3 …')
#    sys.exit()            

#Airbus Logo appears in the header, in every page?  small sampling

file = PyPDF2.PdfFileReader(open('G53RP1609842_issue1.2.pdf', "rb"))

   
page0 = file.getPage(1)
recurse(page0,'first')

page_middle = file.getPage(floor(file.getNumPages()/2))
recurse(page_middle,'middle')

page_end = file.getPage(floor(file.getNumPages()-1))
recurse(page_middle,'end')

print('%s extracted images'% number)
# Out:
# 3 extracted images

# %%
#2.1a Airbus Logo appears in the header, in every page?  small sampling. 
open("first.jpg","rb").read() == open("middle.jpg","rb").read() == open("end.jpg","rb").read()
# Out:
# True

# %%
#2.1b  the total number of pages stated in the first page
0<int(find_between(my_text.lower(), 'nb pages ', 'date' ))<10000
# Out:
# True

# %%
#2.1b  the total number of pages stated in the first page is correct
# file.getNumPages() get number of pages of the pdf file
file.getNumPages()==int(find_between(my_text.lower(), 'nb pages ', 'date' ))
# Out:
# True

# %%
#2.1c the report date is in the correct format on all pages.
import calendar
abbr_to_num = {name: num for num, name in enumerate(calendar.month_abbr) if num}

# %%
abbr_to_num['Apr']
# Out:
# 4

# %%
import re
date=find_between(my_text, 'DATE', 'ATA chapter' ) # WORK JUST FOR A330 NEO 
date=re.sub(' +',' ',date.rstrip())[:15]
string_date=date.replace('\n','')
string_date
# Out:
# '7 Apr 2017'

# %%
print(date)
# Out:
# 7 Apr 2017

# %%
a=find_between(date, ' ', ' ' )
a
# Out:
# 'Apr'

# %%
# Convert string date in a format dd-mm--YYYY
date=date.replace(' '+find_between(date, ' ', ' ')+' ','-'+str(abbr_to_num[a])+'-')

# %%
date=date.lstrip().rstrip()

# %%
print(date)
# Out:
# 7-4-2017

# %%
import datetime



def validate(date_text):
    try:
        datetime.datetime.strptime(date_text, '%d-%m-%Y')
        print('OK, correct date format')
    except ValueError:
        raise ValueError("Incorrect date format, should be dd-Month(as text)-YYYY")

# %%
validate(date)
# Out:
# OK, correct date format

# %%
# 2.1d The copyright year reflects the year of issue.
find_between(my_text, 'AIRBUS S.A.S. ', '. ALL RIGHTS RESERVED.') in date
# Out:
# True

# %%
iss=name.split('_')[1].replace('issue','issue ')
n_issue=iss.replace('issue ','')
n_issue
# Out:
# '1.2'

# %%
#4.1  Record of revision issue same as header
n_issue in find_between(my_text, 'Record of Revisions', string_date)
# Out:
# True

# %%
print(find_between(my_text, 'Table of contents', 'APPENDIX A'))
# Out:
# 1	General Notes	1-1
#
# 1.1	Introduction	1-1
#
# 1.2	FAR/CS Regulations	1-1
#
# 1.3	A/C Data Basis and Main Typical Definition or Options	1-1
#
# 1.4	SRM Principle Description	1-2
#
# 1.4.1	Rework Analysis	1-2
#
# 1.4.1.1	Definition of characteristic rework parameters	1-3
#
# 1.4.1.2	General requirements for reworks	1-4
#
# 1.4.1.3	Definition of the ‘riveted area’ below a stiffener	1-5
#
# 1.4.1.4	Rework diagrams	1-6
#
# 1.4.2	Lightning Strike 50 FC Analysis	1-8
#
# 1.4.2.1	Burn marks on skin only	1-8
#
# 1.4.2.2	Burn marks on existing fastener (skin not affected)	1-9
#
# 1.4.2.3	Burn marks on existing fastener and adjacent skin	1-9
#
# 1.4.3	Lightning Strike Repair Analysis	1-10
#
# 1.4.3.1	Temporary repair	1-10
#
# 1.4.3.1.1	Burn marks on skin	1-10
#
# 1.4.3.1.2	Burn marks on existing fastener	1-11
#
# 1.4.3.1.3	Burn marks on existing fastener and / or adjacent skin	1-11
#
# 1.4.3.1.4	Protruding blind fastener installation	1-12
#
# 1.4.3.2	Permanent repair	1-13
#
# ...

# %%
lines=[]
for line in find_between(my_text, 'Table of contents', 'APPENDIX A').split('\n'):
    lines.append(line)
    print(line)
# Out:
# 1	General Notes	1-1
#
# 1.1	Introduction	1-1
#
# 1.2	FAR/CS Regulations	1-1
#
# 1.3	A/C Data Basis and Main Typical Definition or Options	1-1
#
# 1.4	SRM Principle Description	1-2
#
# 1.4.1	Rework Analysis	1-2
#
# 1.4.1.1	Definition of characteristic rework parameters	1-3
#
# 1.4.1.2	General requirements for reworks	1-4
#
# 1.4.1.3	Definition of the ‘riveted area’ below a stiffener	1-5
#
# 1.4.1.4	Rework diagrams	1-6
#
# 1.4.2	Lightning Strike 50 FC Analysis	1-8
#
# 1.4.2.1	Burn marks on skin only	1-8
#
# 1.4.2.2	Burn marks on existing fastener (skin not affected)	1-9
#
# 1.4.2.3	Burn marks on existing fastener and adjacent skin	1-9
#
# 1.4.3	Lightning Strike Repair Analysis	1-10
#
# 1.4.3.1	Temporary repair	1-10
#
# 1.4.3.1.1	Burn marks on skin	1-10
#
# 1.4.3.1.2	Burn marks on existing fastener	1-11
#
# 1.4.3.1.3	Burn marks on existing fastener and / or adjacent skin	1-11
#
# 1.4.3.1.4	Protruding blind fastener installation	1-12
#
# 1.4.3.2	Permanent repair	1-13
#
# ...

# %%
new_lines=[]
for line in lines:
    
    if line!='':
        new_lines.append(line)

# %%
for line in new_lines:
    print(line)
# Out:
# 1	General Notes	1-1
# 1.1	Introduction	1-1
# 1.2	FAR/CS Regulations	1-1
# 1.3	A/C Data Basis and Main Typical Definition or Options	1-1
# 1.4	SRM Principle Description	1-2
# 1.4.1	Rework Analysis	1-2
# 1.4.1.1	Definition of characteristic rework parameters	1-3
# 1.4.1.2	General requirements for reworks	1-4
# 1.4.1.3	Definition of the ‘riveted area’ below a stiffener	1-5
# 1.4.1.4	Rework diagrams	1-6
# 1.4.2	Lightning Strike 50 FC Analysis	1-8
# 1.4.2.1	Burn marks on skin only	1-8
# 1.4.2.2	Burn marks on existing fastener (skin not affected)	1-9
# 1.4.2.3	Burn marks on existing fastener and adjacent skin	1-9
# 1.4.3	Lightning Strike Repair Analysis	1-10
# 1.4.3.1	Temporary repair	1-10
# 1.4.3.1.1	Burn marks on skin	1-10
# 1.4.3.1.2	Burn marks on existing fastener	1-11
# 1.4.3.1.3	Burn marks on existing fastener and / or adjacent skin	1-11
# 1.4.3.1.4	Protruding blind fastener installation	1-12
# 1.4.3.2	Permanent repair	1-13
# 1.4.3.2.1	Burn marks on skin	1-13
# ...

# %%
print(new_lines[0][-4:].lstrip())
var='1'
l=new_lines[0][-4:].lstrip()
var+'-'== l[0:2]
# Out:
# 1-1
# True

# %%
l[0:2]
# Out:
# '1-'

# %%
new= l.replace(l[0:2],'')
1<=int(new)<=100
# Out:
# True

# %%
new_lines[0][-4:].lstrip()
# Out:
# '1-1'

# %%
# 2.1b the page numbering is correct, in every page
s=0
for line in new_lines:
    start=line[0]
    end=line[-4:].lstrip()
    n_page= end.replace(end[0:2],'')
    
    if (start+'-')==end[0:2] and 1<=int(n_page)<=1000:
        s+=1
        
print(s==len(new_lines))
# Out:
# True

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
headers = [x.blob.decode() for x in document.part.package.parts if x.partname.find('header')>0]

# %%
from lxml import etree

# %%
len(headers)
# Out:
# 20

# %%
#!/usr/bin/env python
# encoding: utf-8

"""
Testing iter_block_items()
"""

from __future__ import (
    absolute_import, division, print_function, unicode_literals
)

from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph

def table_print(block):
    
    table=block
    
    for row in table.rows:
        for cell in row.cells:
            for paragraph in cell.paragraphs:
                print(paragraph.text,'  ',end='')
                #y.write(paragraph.text)
                #y.write('  ')
        print("\n")
        
    
    
    
    


def iter_block_items(parent):
    """
    Generate a reference to each paragraph and table child within *parent*,
    in document order. Each returned value is an instance of either Table or
    Paragraph. *parent* would most commonly be a reference to a main
    Document object, but also works for a _Cell object, which itself can
    contain paragraphs and tables.
    """
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
        # print(parent_elm.xml)
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    else:
        raise ValueError("something's not right")

    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

#for block in iter_block_items(document):
    #print('found one')
    #print(block.text if isinstance(block, Paragraph) else '<table>') 

tables=''    
for block in iter_block_items(document):
                    
    #if isinstance(block, Paragraph):
        #print(block.text)
    if isinstance(block, Table):
        
        #table_print(block)
        table=block
        for row in table.rows:
            for cell in row.cells:
                for paragraph in cell.paragraphs:
                    
                    if paragraph.text=='ASSEMBLY N':
                        print(len(row.cells))
                        print(len(table.rows))

# %%
print(p)
# Out:
#  Location Certification Certification Certification SRM SRM SRM SRM Sizing loadcase Location RFfast shear RFskin bearing RFintern part bearing RFfast shear 0.9 x RFskin bearing RFintern part bearing RFmin Sizing loadcase Str26-27-Fr39.2 1.43 2.84 1.63 1.43 2.55 1.04 1.04 L2_UP_90CMVB01K001 Str15-16-Fr40 1.32 4.50 4.19 1.32 4.05 4.19 1.32 L2_UP_90CWNG00G001 Str16-17-Fr40 1.32 4.50 4.19 1.32 4.05 4.19 1.32 L2_UP_90CWNG00G001

# %%
ap="'"

# %%
print(ap)
# Out:
# '

# %%
print("ciao")
# Out:
# ciao

# %%
text = "This task is valid for A320. This task is not applicable for A319. c"
words = text.split() #note that split without arguments splits on whitespace
pairs = [words[i]+' '+words[i+1] for i in range(len(words)-1)]
print(pairs)
# Out:
# ['This task', 'task is', 'is valid', 'valid for', 'for A320.', 'A320. This', 'This task', 'task is', 'is not', 'not applicable', 'applicable for', 'for A319.', 'A319. c']

# %%
text2 = "This task is applicable for A319. This task is not valid for A320. c"
words2 = text2.split() #note that split without arguments splits on whitespace
pairs2 = [words2[i]+' '+words2[i+1] for i in range(len(words2)-1)]
print(pairs2)
# Out:
# ['This task', 'task is', 'is applicable', 'applicable for', 'for A319.', 'A319. This', 'This task', 'task is', 'is not', 'not valid', 'valid for', 'for A320.', 'A320. c']

# %%
n = []
for index, element in enumerate(pairs2):
    
    if '. ' not in element:
        
        n.append(element)
    
    #print(element)
    #for e in element.split():
     #   if '.' in e:
      #      print(e)
       #     print(True)
        #    if element in pairs2:
                
         #       if index<len(pairs2)-1:
                    
                   # n.append(pairs2[index+1])
                #pairs2.remove(pairs2[index+1])
                
print(n)           
  
'.' in 'A319. '
# Out:
# ['This task', 'task is', 'is applicable', 'applicable for', 'for A319.', 'This task', 'task is', 'is not', 'not valid', 'valid for', 'for A320.']
# True

# %%
print(pairs2)
# Out:
# ['This task', 'task is', 'is applicable', 'applicable for', 'for A319.', 'This task', 'task is', 'is not', 'not valid', 'valid for', 'for A320.']

# %%
for e in 'A319. This'.split():
    print(e)
    print('.' in e)
# Out:
# A319.
# True
# This
# False

# %%
from termcolor import colored


common_pairs=[]
for element in pairs:
    for element2 in pairs2:
        
        if element == element2:
            if element not in common_pairs: 
                common_pairs.append(element)
pairs=set(pairs)
pairs2=set(pairs2)

# %%
print(common_pairs)
print(pairs)
print(pairs2)
# Out:
# ['This task', 'task is', 'valid for', 'for A320.', 'is not', 'applicable for', 'for A319.']
# {'valid for', 'for A320.', 'A319. c', 'A320. This', 'not applicable', 'applicable for', 'is valid', 'for A319.', 'is not', 'This task', 'task is'}
# {'valid for', 'for A320.', 'is applicable', 'A319. This', 'applicable for', 'is not', 'for A319.', 'A320. c', 'This task', 'task is', 'not valid'}

# %%
for element in common_pairs:
    pairs.remove(element)
    pairs2.remove(element)

# %%
print(pairs)
# Out:
# {'A319. c', 'A320. This', 'not applicable', 'is valid'}

# %%
print(pairs2)
# Out:
# {'is applicable', 'A319. This', 'A320. c', 'not valid'}

# %%
for element in pairs:
    for el in element.split():
        text=text.replace(' '+el+' ',' '+colored(el,'red')+' ')
        
print(text)
# Out:
# This task is valid for A320. This task is not applicable for A319. c

# %%
for element in pairs2:
    for el in element.split():
        text2=text2.replace(' '+el+' ',' '+colored(el,'red')+' ')
        
print(text2)
# Out:
# This task is applicable for A319. This task is not valid for A320. c

# %%
common_words = []

c3 = list(filter(lambda x: x in words, words2))
common_words.append(c3)

# %%
print(common_words)
# Out:
# [['This', 'task', 'is', 'applicable', 'for', 'A319.', 'This', 'task', 'is', 'not', 'valid', 'for', 'A320.', 'c']]

# %%
print(text)
# Out:
# ['This', '31mtask', '0m', '31mis', '0m', '31mvalid', '0m', 'for', '31mA320', '0m', '31mThis', '0m', '31mtask', '0m', '31mis', '0m', '31mnot', '0m', '31mapplicable', '0m', 'for', 'A319']

# %%
'the' in 'for the'
# Out:
# True

# %%
l=['allowable damage', '2 sur', 'refer to:', 'of allowable', 'for damage/repair', '51-11-15 a320', 'this task', 'to chapter', 'damage/repair data', '- task', 'data the', 'skin plates', 'the general', 'corroded areas', 'for the', 'of the']

# %%
a=[]
for ll in l:
    if 'the' not in ll:
        a.append(ll)

# %%
print(l)
# Out:
# ['allowable damage', '2 sur', 'refer to:', 'of allowable', 'for damage/repair', '51-11-15 a320', 'this task', 'to chapter', 'damage/repair data', '- task', 'data the', 'skin plates', 'the general', 'corroded areas', 'for the', 'of the']

# %%
print(a)
# Out:
# ['allowable damage', '2 sur', 'refer to:', 'of allowable', 'for damage/repair', '51-11-15 a320', 'this task', 'to chapter', 'damage/repair data', '- task', 'skin plates', 'corroded areas']

# %%
ss=' '.join(l)

# %%
' -' in 'damage -'
# Out:
# True

# %%
l='(1) this task contains  allowable damage data for  skin plates of  nose forward fuselage . allowable damage is damage for which a structural repair is not necessary.'

# %%
l=l.replace('not necessary',colored('not necessary','red'))

# %%
print(l)
# Out:
# (1) this task contains  allowable damage data for  skin plates of  nose forward fuselage . allowable damage is damage for which a structural repair is not necessary.

# %%
print(l.replace('not necessary',colored('not necessary','red')))
# Out:
# (1) this task contains  allowable damage data for  skin plates of  nose forward fuselage . allowable damage is damage for which a structural repair is not necessary.

# %%
a = [210, 20, 2, 6, 210]
b = set(a)

sorted(set(a), key=a.index)
# Out:
# [210, 20, 2, 6]

# %%
'. ' in '3.2'
# Out:
# False

# %%
from termcolor import colored

lll='ciao mi chiamo pinco pallino si proprio cosi pinco pallino'

a= lll.replace('pinco',colored('pinco','red'))
print(a)
print(a.replace(colored('pinco')+' '+'pallino',colored('pinco')+' '+ colored('pallino','red')))
# Out:
# ciao mi chiamo pinco pallino si proprio cosi pinco pallino
# ciao mi chiamo pinco pallino si proprio cosi pinco pallino

# %%
from rpy2.robjects.packages import importr

# %%
import rpy2.robjects.packages as rpackages

# %%
utils = rpackages.importr('utils')

# %%
# select a mirror for R packages
utils.chooseCRANmirror(ind=1) # select the first mirror in the list
# Out:
# rpy2.rinterface.NULL

# %%
packnames = ('magick')
names_to_install = [packnames]
from rpy2.robjects.vectors import StrVector
#if len(names_to_install) > 0:
utils.install_packages(StrVector(names_to_install))
# Out:
# rpy2.rinterface.NULL

# %%
x=Image.open('image21.jpeg','r')
x=x.convert('L') #makes it greyscale
x.save('image21.jpeg')

# %%
tess = importr('tesseract')

# %%
eng=tess.tesseract("eng")
text=tess.ocr('image19.jpeg', engine = eng)

# %%
print(type(str(text)))
# Out:
# <class 'str'>

# %%
a = str(text)
a = a[5:]

# %%
print(a[:-2])
# Out:
# YES DAMAGE WITHIN NO\nRESTRICTIONS?\nDO A DETAILED VISUAL\nINSPECTION TO FIND THE CRACK.\nCRACK FOUND? YES DO A REPAIR, SEE 53-11-11- REPAIR\n' OR CONTACT AIRBUS.\nNO\nDAMAGE Is ACCEPTABLE\nFOR 50 FC (FH NOT RELEVANT).\n&\nSKETCH 1\n\nNOTE:\nRESTRICTIONS:\n\nCASE1IFOR MAXIMUM NUMBER OF BURNED FASTENERS IN ANY ROW\n\nOF FASTENER (SEE FIGURE 007).\n\nCASE 2: IN CIRCUMFERENTIAL JOINTS ONE BURNED FASTENER PER STRINGER BAY AND\n\nPER SKIN PANEL (SEE FIGURE 005).\n\nCASE 3: IN LONGITUDINAL JOINTS N0 ADJACENT BURNED FASTENERS PER RIVET LINE\n\nAND NOT MORE THAN TWO BURNED FASTENERS PER FRAME BAY (SEE FIGURE 006)‘\nAPPLICABLE FOR BURN MARKS 0N EXISTING RlVETS/FASTENERS AND ADJACENT SKIN\nCAUSED BY LIGHTNING STRIKES.\nMAX LENGTH OF THE DAMAGE SEE SKETCH 1: L MAX 3 25% OF EXISTING\nFASTENERIR'VET P'TCH- N_SR_531111_1_5FLMDODC_01_00\n\n

# %%
print(a.replace('\\n',' '))
# Out:
# [1] "YES DAMAGE WITHIN NO RESTRICTIONS? DO A DETAILED VISUAL INSPECTION TO FIND THE CRACK. CRACK FOUND? YES DO A REPAIR, SEE 53-11-11- REPAIR ' OR CONTACT AIRBUS. NO DAMAGE Is ACCEPTABLE FOR 50 FC (FH NOT RELEVANT). & SKETCH 1  NOTE: RESTRICTIONS:  CASE1IFOR MAXIMUM NUMBER OF BURNED FASTENERS IN ANY ROW  OF FASTENER (SEE FIGURE 007).  CASE 2: IN CIRCUMFERENTIAL JOINTS ONE BURNED FASTENER PER STRINGER BAY AND  PER SKIN PANEL (SEE FIGURE 005).  CASE 3: IN LONGITUDINAL JOINTS N0 ADJACENT BURNED FASTENERS PER RIVET LINE  AND NOT MORE THAN TWO BURNED FASTENERS PER FRAME BAY (SEE FIGURE 006)‘ APPLICABLE FOR BURN MARKS 0N EXISTING RlVETS/FASTENERS AND ADJACENT SKIN CAUSED BY LIGHTNING STRIKES. MAX LENGTH OF THE DAMAGE SEE SKETCH 1: L MAX 3 25% OF EXISTING FASTENERIR'VET P'TCH- N_SR_531111_1_5FLMDODC_01_00  "

# %%
import re

# %%
b='['+ re.findall('\d',a)+']'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-956f1b7e7199> in <module>()
# ----> 1 b='['+ re.findall('\d',a)+']'
#
# TypeError: must be str, not list

# %%
' '.join(re.findall('\d',a))
# Out:
# '1 0 5 3 1 1 1 1 5 0 1 1 8 0 7 0 9 0 0 2 0 2 5 7 2 0 2 8 3 2 1 5 0 5 9 6 0 2 3 6 2 1 8 0 7 0 9 0 0 3 7 2 0 2 8 3 2 5 4 1 5 2 5 4 1 2 2 0 0 7 9 3 2 0 1 2 6 5 3 1 1 1 1 1 5 0 0 0 0 1 0 0'

# %%
from PIL import Image
import numpy as np

im = Image.open("image21.jpeg")
pix = np.asarray(im)
pix = pix[:,:,0:3] # Drop the alpha channel
#pix = 255 - pix  # Invert the image
#H =  pix.sum(axis=2).sum(axis=1) # Sum the colors, then the y-axis

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(H)

# %%
idx = np.where(pix-255)[0:2]

# %%
box=map(list((min,idx))[::-1]) + map(list((max,idx))[::-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-995a08974c7b> in <module>()
# ----> 1 box=map(list((min,idx))[::-1]) + map(list((max,idx))[::-1])
#
# TypeError: map() must have at least two arguments.

# %%
from pylab import * 

imshow(pix[1200:,:,:])

# %%
imshow(pix)

# %%
img = Image.fromarray(pix[1200:,:,:], 'RGB')

# %%
img.save('my.png')

# %%
eng=tess.tesseract("eng")
text=tess.ocr('my.png', engine = eng)

# %%
print(text)
# Out:
# [1] "NOTE:\nMINIMUM 2.5 X(D1+ 02).\nNOT MORE THAN THREE BURN MARKS WITHIN 60 mm (2.36 in) IN LONGITUDINAL DIRECTION\n. BURN MARK (5 MAX).\n+ REFERENCE ONLY.\nD1AND D2 = MAXIMUM DIAMETER OF BURN MARK.\nD1 AND DZ S 7-2 mm (0283 \"”- N78R75311117175FNM000A701700\n\n"
